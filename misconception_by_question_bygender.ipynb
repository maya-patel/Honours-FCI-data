# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from FCI_functions import calculate_post_score, calculate_pre_score, calculate_question_score_post, calculate_question_score_pre, calculate_pre_score_2020, calculate_post_score_2020, calculate_question_score_pre_2020 , calculate_question_score_post_2020, calculate_question_score_pre_2021, calculate_question_score_post_2021, calculate_question_score_post_2021_err

# %%
df16_111 = pd.read_excel('rawdata/2016-17 WT1 Phys 111 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df16_112 = pd.read_excel('rawdata/2016-17 WT1 Phys 112 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df14_111 = pd.read_excel('rawdata/2014-15 WT1 Phys 111 ALL Data - Shared with Chelsea (20210212).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df14_112 = pd.read_excel('rawdata/2014-15 WT1 Phys 112 ALL Data - Shared with Chelsea (20210212).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df15_111 = pd.read_excel('rawdata/2015-16 WT1 Phys 111 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df15_112 = pd.read_excel('rawdata/2015-16 WT1 Phys 112 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df17_111 = pd.read_excel('rawdata/2017-18 WT1 Phys 111 ALL Data - Shared with David (20190612).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df17_112 = pd.read_excel('rawdata/2017-18 WT1 Phys 112 ALL Data - Shared with David (20190612).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df18_111 = pd.read_excel('rawdata/2018-19 WT1 Phys 111 ALL Data - Shared with David (20190530).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df18_112 = pd.read_excel('rawdata/2018-19 WT1 Phys 112 ALL Data - Shared with David (20190527).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)#.drop(df18_112[df18_112['Secondary'] == L15].index)
df19_111 = pd.read_excel('rawdata/2019-20 WT1 Phys 111 ALL Data - Shared with Maya (20211222).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df19_112 = pd.read_excel('rawdata/2019-20 WT1 Phys 112 ALL Data - Shared with Maya (20211222).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df20 = pd.read_excel('rawdata/2020-21 WT1 Phys 111&112 ALL Data - Shared with Chelsea (20210329).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
is_111 = df20['Course'] == 111
df20_111 = df20[is_111]
is_112 = df20['Course'] == 112
df20_112 = df20[is_112]

df21_111 = pd.read_excel('2021raw_corrected.xlsx')

# %%
df14_111_f = df14_111[df14_111['PRE Q85']== 'A']
df14_112_f = df14_112[df14_112['PRE Q85']== 'A']
df15_111_f = df15_111[df15_111['PRE Q85']== 'A']
df15_112_f = df15_112[df15_112['PRE Q85']== 'A']
df16_111_f = df16_111[df16_111['PRE Q85']== 'A']
df16_112_f = df16_112[df16_112['PRE Q85']== 'A']
df17_111_f = df17_111[df17_111['PRE Q85']== 'A']
df17_112_f = df17_112[df17_112['PRE Q85']== 'A']
df18_111_f = df18_111[df18_111['PRE Q85']== 'A']
df18_112_f = df18_112[df18_112['PRE Q85']== 'A']
df19_111_f = df19_111[df19_111['PRE Q85']== 'A']
df19_112_f = df19_112[df19_112['PRE Q85']== 'A']

# %%
def calculate_scores(df):
    df_result = pd.DataFrame()
    df_result["PRE Q1"] = (df["PRE Q1"].value_counts())
    df_result["PRE Q2"] = (df["PRE Q2"].value_counts())
    df_result["PRE Q3"] = (df["PRE Q3"].value_counts())
    df_result["PRE Q4"] = (df["PRE Q4"].value_counts())
    df_result["PRE Q5"] = (df["PRE Q5"].value_counts())
    df_result["PRE Q6"] = (df["PRE Q6"].value_counts())
    df_result["PRE Q7"] = (df["PRE Q7"].value_counts())
    df_result["PRE Q8"] = (df["PRE Q8"].value_counts())
    df_result["PRE Q9"] = (df["PRE Q9"].value_counts())
    df_result["PRE Q10"] = (df["PRE Q10"].value_counts())
    df_result["PRE Q11"] = (df["PRE Q11"].value_counts())
    df_result["PRE Q12"] = (df["PRE Q12"].value_counts())
    df_result["PRE Q13"] = (df["PRE Q13"].value_counts())
    df_result["PRE Q14"] = (df["PRE Q14"].value_counts())
    df_result["PRE Q15"] = (df["PRE Q15"].value_counts())
    df_result["PRE Q16"] = (df["PRE Q16"].value_counts())
    df_result["PRE Q17"] = (df["PRE Q17"].value_counts())
    df_result["PRE Q18"] = (df["PRE Q18"].value_counts())
    df_result["PRE Q19"] = (df["PRE Q19"].value_counts())
    df_result["PRE Q20"] = (df["PRE Q20"].value_counts())
    df_result["PRE Q21"] = (df["PRE Q21"].value_counts())
    df_result["PRE Q22"] = (df["PRE Q22"].value_counts())
    df_result["PRE Q23"] = (df["PRE Q23"].value_counts())
    df_result["PRE Q24"] = (df["PRE Q24"].value_counts())
    df_result["PRE Q25"] = (df["PRE Q25"].value_counts())
    df_result["PRE Q26"] = (df["PRE Q26"].value_counts())
    df_result["PRE Q27"] = (df["PRE Q27"].value_counts())
    df_result["PRE Q28"] = (df["PRE Q28"].value_counts())
    df_result["PRE Q29"] = (df["PRE Q29"].value_counts())
    df_result["PRE Q30"] = (df["PRE Q30"].value_counts())

    return df_result

# %%
(calculate_scores(df14_111)["PRE Q30"].B+calculate_scores(df14_111)["PRE Q30"].D+calculate_scores(df14_111)["PRE Q30"].E)/calculate_scores(df14_111)["PRE Q30"].sum()
# Out:
# 0.7114093959731543

# %%
def calculate_misconceptions(df):
    df_results = [0] * 32
    df_results[0] = (df["PRE Q1"].D + df["PRE Q1"].E)/df["PRE Q1"].sum()
    df_results[1] = (df["PRE Q2"].B + df["PRE Q2"].C)/df["PRE Q2"].sum()
    df_results[2] = (df["PRE Q3"].A)/df["PRE Q3"].sum()
    df_results[3] = (df["PRE Q4"].A)/df["PRE Q4"].sum()
    df_results[4] = (df["PRE Q5"].E)/df["PRE Q5"].sum()
    df_results[5] = (df["PRE Q5"].C+df["PRE Q5"].D)/df["PRE Q5"].sum()
    df_results[6] = (df["PRE Q6"].A)/df["PRE Q6"].sum()
    df_results[7] = (df["PRE Q6"].C+df["PRE Q6"].D+df["PRE Q6"].E)/df["PRE Q6"].sum()
    df_results[8] = (df["PRE Q7"].A)/df["PRE Q7"].sum()
    df_results[9] = (df["PRE Q7"].E)/df["PRE Q7"].sum()
    df_results[10] = (df["PRE Q8"].A)/df["PRE Q8"].sum()
    df_results[11] = (df["PRE Q9"].C)/df["PRE Q9"].sum()
    df_results[12] = (df["PRE Q9"].D)/df["PRE Q9"].sum()
    df_results[13] = (df["PRE Q10"].B + df["PRE Q10"].C)/df["PRE Q10"].sum()
    df_results[14] = (df["PRE Q11"].B + df["PRE Q11"].C)/df["PRE Q11"].sum()
    df_results[15] = (df["PRE Q13"].A+df["PRE Q13"].B+df["PRE Q13"].C)/df["PRE Q13"].sum()
    df_results[16] = (df["PRE Q13"].E)/df["PRE Q13"].sum()
    df_results[17] = (df["PRE Q14"].E)/df["PRE Q14"].sum()
    df_results[18] = (df["PRE Q15"].B)/df["PRE Q15"].sum()
    df_results[19] = (df["PRE Q16"].B)/df["PRE Q16"].sum()
    df_results[20] = (df["PRE Q17"].A)/df["PRE Q17"].sum()
    df_results[21] = (df["PRE Q18"].C+df["PRE Q18"].D+df["PRE Q18"].E)/df["PRE Q18"].sum()
    df_results[22] = (df["PRE Q19"].A)/df["PRE Q19"].sum()
    df_results[23] = (df["PRE Q20"].A+df["PRE Q20"].C)/df["PRE Q20"].sum()
    df_results[24] = (df["PRE Q25"].D)/df["PRE Q25"].sum()
    df_results[25] = (df["PRE Q25"].E)/df["PRE Q25"].sum()
    df_results[26] = (df["PRE Q26"].A+df["PRE Q26"].B)/df["PRE Q26"].sum()
    df_results[27] = (df["PRE Q27"].A)/df["PRE Q27"].sum()
    df_results[28] = (df["PRE Q28"].D)/df["PRE Q28"].sum()
    df_results[29] = (df["PRE Q29"].E)/df["PRE Q29"].sum()
    df_results[30] = (df["PRE Q29"].C+df["PRE Q29"].D)/df["PRE Q29"].sum()
    df_results[31] = (df["PRE Q30"].B+df["PRE Q30"].D+df["PRE Q30"].E)/df["PRE Q30"].sum()
    
    return df_results

# %%
column_names=["PRE Q1", "PRE Q2", "PRE Q3", "PRE Q4", "PRE Q5 32", "PRE Q5 22",
             "PRE Q6 31", "PRE Q6 19", "PRE Q7 31", "PRE Q7 19", "PRE Q8",
             "PRE Q9 66", "PRE Q9 9", "PRE Q10 21", "PRE Q11", "PRE Q13 77 22",
             "PRE Q13 69", "PRE Q14", "PRE Q15", "PRE Q16", "PRE Q17", "PRE Q18", 
             "PRE Q19", "PRE 20", "PRE Q25 76", "PRE Q25 24", "PRE Q26", "PRE Q27",
             "PRE Q28", "PRE Q29 28", "PRE Q29 air", "PRE Q30"]
df1 = pd.DataFrame(columns=column_names)

df1.loc["2014 111"] = calculate_misconceptions(calculate_scores(df14_111_f))
df1.loc["2014 112"] = calculate_misconceptions(calculate_scores(df14_112_f))
df1.loc["2015 111"] = calculate_misconceptions(calculate_scores(df15_111_f))
df1.loc["2015 112"] = calculate_misconceptions(calculate_scores(df15_112_f))
df1.loc["2016 111"] = calculate_misconceptions(calculate_scores(df16_111_f))
df1.loc["2016 112"] = calculate_misconceptions(calculate_scores(df16_112_f))
df1.loc["2017 111"] = calculate_misconceptions(calculate_scores(df17_111_f))
df1.loc["2017 112"] = calculate_misconceptions(calculate_scores(df17_112_f))
df1.loc["2018 111"] = calculate_misconceptions(calculate_scores(df18_111_f))
df1.loc["2018 112"] = calculate_misconceptions(calculate_scores(df18_112_f))
df1.loc["2019 111"] = calculate_misconceptions(calculate_scores(df19_111_f))
df1.loc["2019 112"] = calculate_misconceptions(calculate_scores(df19_112_f))
df1.loc["mean"] = df1.mean()
df1.to_excel("misconception_by_question_pre_f.xlsx")
df1
# Out:
#             PRE Q1    PRE Q2    PRE Q3    PRE Q4  PRE Q5 32  PRE Q5 22  \
# 2014 111  0.156863  0.274510  0.117647  0.627451   0.196078   0.607843
# 2014 112  0.333333  0.281818  0.225225  0.736364   0.198198   0.612613
# 2015 111  0.162791  0.294118  0.186047  0.732558   0.176471   0.505882
# 2015 112  0.212598  0.312500  0.257812  0.734375   0.226562   0.609375
# 2016 111  0.247312  0.271739  0.086022  0.706522   0.225806   0.548387
# 2016 112  0.288235  0.295858  0.170588  0.705882   0.202381   0.630952
# 2017 111  0.254545  0.181818  0.181818  0.545455   0.181818   0.527273
# 2017 112  0.300613  0.302469  0.223602  0.785276   0.246914   0.561728
# 2018 111  0.217391  0.195652  0.173913  0.608696   0.239130   0.434783
# 2018 112  0.255319  0.329787  0.212766  0.680851   0.244681   0.537234
# 2019 111  0.187500  0.340426  0.145833  0.604167   0.104167   0.604167
# 2019 112  0.307292  0.338542  0.155440  0.678756   0.162304   0.722513
# ...

# %%
def calculate_scores_post(df):
    df_result = pd.DataFrame()
    df_result["POST Q1"] = (df["POST Q1"].value_counts())
    df_result["POST Q2"] = (df["POST Q2"].value_counts())
    df_result["POST Q3"] = (df["POST Q3"].value_counts())
    df_result["POST Q4"] = (df["POST Q4"].value_counts())
    df_result["POST Q5"] = (df["POST Q5"].value_counts())
    df_result["POST Q6"] = (df["POST Q6"].value_counts())
    df_result["POST Q7"] = (df["POST Q7"].value_counts())
    df_result["POST Q8"] = (df["POST Q8"].value_counts())
    df_result["POST Q9"] = (df["POST Q9"].value_counts())
    df_result["POST Q10"] = (df["POST Q10"].value_counts())
    df_result["POST Q11"] = (df["POST Q11"].value_counts())
    df_result["POST Q12"] = (df["POST Q12"].value_counts())
    df_result["POST Q13"] = (df["POST Q13"].value_counts())
    df_result["POST Q14"] = (df["POST Q14"].value_counts())
    df_result["POST Q15"] = (df["POST Q15"].value_counts())
    df_result["POST Q16"] = (df["POST Q16"].value_counts())
    df_result["POST Q17"] = (df["POST Q17"].value_counts())
    df_result["POST Q18"] = (df["POST Q18"].value_counts())
    df_result["POST Q19"] = (df["POST Q19"].value_counts())
    df_result["POST Q20"] = (df["POST Q20"].value_counts())
    df_result["POST Q21"] = (df["POST Q21"].value_counts())
    df_result["POST Q22"] = (df["POST Q22"].value_counts())
    df_result["POST Q23"] = (df["POST Q23"].value_counts())
    df_result["POST Q24"] = (df["POST Q24"].value_counts())
    df_result["POST Q25"] = (df["POST Q25"].value_counts())
    df_result["POST Q26"] = (df["POST Q26"].value_counts())
    df_result["POST Q27"] = (df["POST Q27"].value_counts())
    df_result["POST Q28"] = (df["POST Q28"].value_counts())
    df_result["POST Q29"] = (df["POST Q29"].value_counts())
    df_result["POST Q30"] = (df["POST Q30"].value_counts())

    return df_result

# %%
def calculate_misconceptions_post(df):
    df_results = [0] * 32
    df_results[0] = (df["POST Q1"].D + df["POST Q1"].E)/df["POST Q1"].sum()
    df_results[1] = (df["POST Q2"].B + df["POST Q2"].C)/df["POST Q2"].sum()
    df_results[2] = (df["POST Q3"].A)/df["POST Q3"].sum()
    df_results[3] = (df["POST Q4"].A)/df["POST Q4"].sum()
    df_results[4] = (df["POST Q5"].E)/df["POST Q5"].sum()
    df_results[5] = (df["POST Q5"].C+df["POST Q5"].D+df["POST Q5"].E)/df["POST Q5"].sum()
    df_results[6] = (df["POST Q6"].A)/df["POST Q6"].sum()
    df_results[7] = (df["POST Q6"].C+df["POST Q6"].D+df["POST Q6"].E)/df["POST Q6"].sum()
    df_results[8] = (df["POST Q7"].A)/df["POST Q7"].sum()
    df_results[9] = (df["POST Q7"].E)/df["POST Q7"].sum()
    df_results[10] = (df["POST Q8"].A)/df["POST Q8"].sum()
    df_results[11] = (df["POST Q9"].C)/df["POST Q9"].sum()
    df_results[12] = (df["POST Q9"].D)/df["POST Q9"].sum()
    df_results[13] = (df["POST Q10"].B + df["POST Q10"].C)/df["POST Q10"].sum()
    df_results[14] = (df["POST Q11"].B + df["POST Q11"].C)/df["POST Q11"].sum()
    df_results[15] = (df["POST Q13"].A+df["POST Q13"].B+df["POST Q13"].C)/df["POST Q13"].sum()
    df_results[16] = (df["POST Q13"].E)/df["POST Q13"].sum()
    df_results[17] = (df["POST Q14"].E)/df["POST Q14"].sum()
    df_results[18] = (df["POST Q15"].B)/df["POST Q15"].sum()
    df_results[19] = (df["POST Q16"].B)/df["POST Q16"].sum()
    df_results[20] = (df["POST Q17"].A)/df["POST Q17"].sum()
    df_results[21] = (df["POST Q18"].C+df["POST Q18"].D+df["POST Q18"].E)/df["POST Q18"].sum()
    df_results[22] = (df["POST Q19"].A)/df["POST Q19"].sum()
    df_results[23] = (df["POST Q20"].A+df["POST Q20"].C)/df["POST Q20"].sum()
    df_results[24] = (df["POST Q25"].D)/df["POST Q25"].sum()
    df_results[25] = (df["POST Q25"].E)/df["POST Q25"].sum()
    df_results[26] = (df["POST Q26"].A+df["POST Q26"].B)/df["POST Q26"].sum()
    df_results[27] = (df["POST Q27"].A)/df["POST Q27"].sum()
    df_results[28] = (df["POST Q28"].D)/df["POST Q28"].sum()
    df_results[29] = (df["POST Q29"].E)/df["POST Q29"].sum()
    df_results[30] = (df["POST Q29"].C+df["POST Q29"].D)/df["POST Q29"].sum()
    df_results[31] = (df["POST Q30"].B+df["POST Q30"].D+df["POST Q30"].E)/df["POST Q30"].sum()
    
    return df_results

# %%
column_names=["POST Q1", "POST Q2", "POST Q3", "POST Q4", "POST Q5 32", "POST Q5 22",
             "POST Q6 31", "POST Q6 19", "POST Q7 31", "POST Q7 19", "POST Q8",
             "POST Q9 66", "POST Q9 9", "POST Q10 21", "POST Q11", "POST Q13 77 22",
             "POST Q13 69", "POST Q14", "POST Q15", "POST Q16", "POST Q17", "POST Q18", 
             "POST Q19", "POST 20", "POST Q25 76", "POST Q25 24", "POST Q26", "POST Q27",
             "POST Q28", "POST Q29 28", "POST Q29 air", "POST Q30"]
df2 = pd.DataFrame(columns=column_names)

df2.loc["2014 111"] = calculate_misconceptions_post(calculate_scores_post(df14_111_f))
df2.loc["2014 112"] = calculate_misconceptions_post(calculate_scores_post(df14_112_f))
df2.loc["2015 111"] = calculate_misconceptions_post(calculate_scores_post(df15_111_f))
df2.loc["2015 112"] = calculate_misconceptions_post(calculate_scores_post(df15_112))
df2.loc["2016 111"] = calculate_misconceptions_post(calculate_scores_post(df16_111))
df2.loc["2016 112"] = calculate_misconceptions_post(calculate_scores_post(df16_112))
df2.loc["2017 111"] = calculate_misconceptions_post(calculate_scores_post(df17_111))
df2.loc["2017 112"] = calculate_misconceptions_post(calculate_scores_post(df17_112))
df2.loc["2018 111"] = calculate_misconceptions_post(calculate_scores_post(df18_111))
df2.loc["2018 112"] = calculate_misconceptions_post(calculate_scores_post(df18_112))
df2.loc["2019 111"] = calculate_misconceptions_post(calculate_scores_post(df19_111))
df2.loc["2019 112"] = calculate_misconceptions_post(calculate_scores_post(df19_112))
df2.loc["mean"] = df2.mean()
df2.loc['std'] = df2.std()
df2.to_excel("misconception_by_question_POST_f.xlsx")
df2
# Out:
#            POST Q1   POST Q2   POST Q3   POST Q4  POST Q5 32  POST Q5 22  \
# 2014 111  0.099338  0.251656  0.264901  0.258278    0.066225    0.496689
# 2014 112  0.161616  0.409091  0.287879  0.570707    0.252525    0.792929
# 2015 111  0.116402  0.255319  0.280423  0.380952    0.116402    0.507937
# 2015 112  0.098361  0.383673  0.254098  0.409836    0.106557    0.561475
# 2016 111  0.105882  0.294118  0.231373  0.363636    0.149606    0.539370
# 2016 112  0.160448  0.309701  0.134831  0.291045    0.111940    0.518657
# 2017 111  0.148148  0.287234  0.226316  0.273684    0.094737    0.510526
# 2017 112  0.179487  0.368613  0.532847  0.175182    0.102564    0.479853
# 2018 111  0.158824  0.251497  0.405882  0.535294    0.152941    0.617647
# 2018 112  0.197880  0.392857  0.607774  0.148410    0.123675    0.678445
# 2019 111  0.114286  0.233333  0.423810  0.200000    0.061905    0.404762
# 2019 112  0.189024  0.327217  0.506098  0.149390    0.109756    0.594512
# ...
