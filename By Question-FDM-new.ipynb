# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from FCI_functions.FCI_functions import calculate_pre_score, calculate_post_score, calculate_question_score_post, calculate_question_score_pre

# %%
df16_111 = pd.read_excel('rawdata/2016-17 WT1 Phys 111 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df16_112 = pd.read_excel('rawdata/2016-17 WT1 Phys 112 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df14_111 = pd.read_excel('rawdata/2014-15 WT1 Phys 111 ALL Data - Shared with Chelsea (20210212).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df14_112 = pd.read_excel('rawdata/2014-15 WT1 Phys 112 ALL Data - Shared with Chelsea (20210212).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df15_111 = pd.read_excel('rawdata/2015-16 WT1 Phys 111 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df15_112 = pd.read_excel('rawdata/2015-16 WT1 Phys 112 ALL Data - Shared with Chelsea.xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df17_111 = pd.read_excel('rawdata/2017-18 WT1 Phys 111 ALL Data - Shared with David (20190612).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df17_112 = pd.read_excel('rawdata/2017-18 WT1 Phys 112 ALL Data - Shared with David (20190612).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df18_111 = pd.read_excel('rawdata/2018-19 WT1 Phys 111 ALL Data - Shared with David (20190530).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df18_112 = pd.read_excel('rawdata/2018-19 WT1 Phys 112 ALL Data - Shared with David (20190527).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df19_111 = pd.read_excel('rawdata/2019-20 WT1 Phys 111 ALL Data - Shared with Maya (20211222).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df19_112 = pd.read_excel('rawdata/2019-20 WT1 Phys 112 ALL Data - Shared with Maya (20211222).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
df20 = pd.read_excel('rawdata/2020-21 WT1 Phys 111&112 ALL Data - Shared with Chelsea (20210329).xlsx').replace(["BLANK", "!!", "MULT"], np.nan)
is_111 = df20['Course'] == 111
df20_111 = df20[is_111]
is_112 = df20['Course'] == 112
df20_112 = df20[is_112]

# %%
def calculate_pre_score_FDM(student):
    corr_ans = ['C' , 'D', 'B' , 'C', 'B' , 'C' , 'E', 'A', 'C' , 'D' , 'E', 'A']
    score = 0
    questions = [5, 5, 11, 11, 13, 13, 13, 17, 18, 18, 18, 27]
    for i in range(12):
        string = "PRE Q"+ str(questions[i])
        if string in student:
            if student[string]==corr_ans[i]:
                score+=1
            
    return (score)

# %%
def calculate_pre_score_FDM_2020(student):
    corr_ans = [3 , 4, 2 , 3, 2 , 3 , 5, 1, 3 , 4 , 5, 1]
    score = 0
    questions = [5, 5, 11, 11, 13, 13, 13, 17, 18, 18, 18, 27]
    for i in range(12):
        string = "PRE Q"+ str(questions[i])
        if string in student:
            if student[string]==corr_ans[i]:
                score+=1
            
    return (score)

# %%
def calculate_post_score_FDM(student):
    corr_ans = ['C' , 'D', 'B' , 'C', 'B' , 'C' , 'E', 'A', 'C' , 'D' , 'E', 'A']
    score = 0
    questions = [5, 5, 11, 11, 13, 13, 13, 17, 18, 18, 18, 27]
    for i in range(12):
        string = "POST Q"+ str(questions[i])
        if string in student:
            if student[string]==corr_ans[i]:
                score+=1
            
    return (score)

# %%
def calculate_post_score_FDM_2020(student):
    corr_ans = [3 , 4, 2 , 3, 2 , 3 , 5, 1, 3 , 4 , 5, 1]
    score = 0
    questions = [5, 5, 11, 11, 13, 13, 13, 17, 18, 18, 18, 27]
    for i in range(12):
        string = "POST Q"+ str(questions[i])
        if string in student:
            if student[string]==corr_ans[i]:
                score+=1
            
    return (score)

# %%
def FDM(df111, df112):
    df111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    df111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    plt.legend(["pre", "post"])
    plt.title("111")
    plt.ylim(0,140)
    plt.show()

    df112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    df112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    plt.legend(["pre", "post"])
    plt.title("112")
    plt.show()

    is_f111 = df111['PRE Q85']== 'A'
    df_f111 = df111[is_f111]
    
    is_f112 = df112['PRE Q85']== 'A'
    df_f112 = df112[is_f112]

    df_f111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    df_f111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    plt.legend(["pre", "post"])
    plt.title("Female 111")
    plt.show()
    
    df_f112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    df_f112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
    plt.legend(["pre", "post"])
    plt.title("Female 112")
    plt.show()

# %%
FDM(df14_111, df14_112)

# %%
df14_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df14_111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df14_111", "df14_112"])
plt.title("111")
plt.ylim(0,140)
plt.show()

df14_112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df14_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df14_111", "df14_112"])
plt.title("112")
plt.show()

is_f = df14_111['PRE Q85']== 'A'
df_f = df14_111[is_f]

df_f.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df_f.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["111", "112"])
plt.title("Female")
plt.show()

# %%
df15_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df15_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df15_111", "df15_112"])
plt.title("pre")
plt.show()

df15_111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df15_112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df15_111", "df15_112"])
plt.title("Post")
plt.ylim(0,80)
plt.show()

# %%
df16_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df16_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df16_111", "df16_112"])
plt.title("pre")
plt.show()

df16_111.dropna(thresh=80, axis=0).apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df16_112.dropna(thresh=80, axis=0).apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df16_111", "df16_112"])
plt.title("Post")
plt.ylim(0,80)
plt.show()
print(df16_111.dropna(thresh=60, axis=0).apply(calculate_post_score_FDM, axis=1).value_counts().sum())
print(df16_112.dropna(thresh=80, axis=0).apply(calculate_post_score_FDM, axis=1).value_counts().sum())
# Out:
# 245
# 254

# %%
df17_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df17_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df17_111", "df17_112"])
plt.title("pre")
plt.ylim(0,160)
plt.show()

df17_111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df17_112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df17_111", "df17_112"])
plt.title("Post")
plt.show()

# %%
df18_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df18_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df18_111", "df18_112"])
plt.title("pre")
plt.show()

df18_111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df18_112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df18_111", "df18_112"])
plt.title("Post")
plt.ylim(0,100)
plt.show()

# %%
df19_111.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df19_112.apply(calculate_pre_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df19_111", "df19_112"])
plt.title("pre")
plt.show()

df19_111.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
df19_112.apply(calculate_post_score_FDM, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df19_111", "df19_112"])
plt.title("Post")
#plt.ylim(0,100)
plt.show()

# %%
df20_111.apply(calculate_pre_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
df20_112.apply(calculate_pre_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df20_111", "df20_112"])
plt.title("pre")
plt.ylim(0,140)
plt.show()
df20_111.apply(calculate_post_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
df20_112.apply(calculate_post_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
plt.legend(["df20_111", "df20_112"])
plt.title("post")
plt.ylim(0,140)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c9a00e97e36e> in <module>
#       5 plt.ylim(0,140)
#       6 plt.show()
# ----> 7 df20_111.apply(calculate_post_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
#       8 df20_112.apply(calculate_post_score_FDM_2020, axis=1).plot.hist(alpha=0.5, bins=7)
#       9 plt.legend(["df20_111", "df20_112"])
#
# NameError: name 'calculate_post_score_FDM_2020' is not defined

# %%
print(df14_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df14_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df15_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df15_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df16_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df16_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df17_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df17_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df18_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)
print(df18_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)
# Out:
# 0.30588235294117644
# 0.5524934383202099
# 0.5441860465116279
# 0.5782556750298685
# 0.47575757575757577
# 0.6288659793814433
# 0.28311258278145696
# 0.4327335047129392
# 0.4522569444444444
# 0.616822429906542

# %%
print(df14_111.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df14_112.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df15_111.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df15_112.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df16_111.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df16_112.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df17_111.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df17_112.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df18_111.apply(calculate_post_score_FDM, axis=1).mean()/6)
print(df18_112.apply(calculate_post_score_FDM, axis=1).mean()/6)
# Out:
# 0.22352941176470587
# 0.46719160104986873
# 0.3364341085271318
# 0.4271206690561529
# 0.34848484848484845
# 0.424971363115693
# 0.23013245033112584
# 0.2879177377892031
# 0.4123263888888889
# 0.44911734164070616

# %%
print((df14_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df14_111.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df14_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df14_112.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df15_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df15_111.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df15_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df15_112.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df16_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df16_111.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df16_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df16_112.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df17_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df17_111.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df17_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df17_112.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df18_111.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df18_111.apply(calculate_post_score_FDM, axis=1).mean()/6))
print((df18_112.apply(calculate_pre_score_FDM, axis=1).mean()/6)-(df18_112.apply(calculate_post_score_FDM, axis=1).mean()/6))
# Out:
# 0.08235294117647057
# 0.08530183727034119
# 0.20775193798449615
# 0.1511350059737156
# 0.12727272727272732
# 0.20389461626575028
# 0.05298013245033112
# 0.1448157669237361
# 0.039930555555555525
# 0.16770508826583586

# %%
column_names=[]
for i in range(1, 31):
    column_names.append("PRE Q" + str(i))
df1 = pd.DataFrame(columns=column_names)

df1.loc["2014 111"] = calculate_question_score_pre(df14_111)
df1.loc["2014 112"] = calculate_question_score_pre(df14_112)
df1.loc["2015 111"] = calculate_question_score_pre(df15_111)
df1.loc["2015 112"] = calculate_question_score_pre(df15_112)
df1.loc["2016 111"] = calculate_question_score_pre(df16_111)
df1.loc["2016 112"] = calculate_question_score_pre(df16_112)
df1.loc["2017 111"] = calculate_question_score_pre(df17_111)
df1.loc["2017 112"] = calculate_question_score_pre(df17_112)
df1.loc["2018 111"] = calculate_question_score_pre(df18_111)
df1.loc["2018 112"] = calculate_question_score_pre(df18_112)
df1.loc["mean"] = df1.mean()

df1.to_excel("Pre_test_by_question.xlsx")

# %%
column_names=[]
for i in range(1, 31):
    column_names.append("POST Q" + str(i))
df2 = pd.DataFrame(columns=column_names)

df2.loc["2014 111"] = calculate_question_score_post(df14_111)
df2.loc["2014 112"] = calculate_question_score_post(df14_112)
df2.loc["2015 111"] = calculate_question_score_post(df15_111)
df2.loc["2015 112"] = calculate_question_score_post(df15_112)
df2.loc["2016 111"] = calculate_question_score_post(df16_111)
df2.loc["2016 112"] = calculate_question_score_post(df16_112)
df2.loc["2017 111"] = calculate_question_score_post(df17_111)
df2.loc["2017 112"] = calculate_question_score_post(df17_112)
df2.loc["2018 111"] = calculate_question_score_post(df18_111)
df2.loc["2018 112"] = calculate_question_score_post(df18_112)
df2.loc["mean"] = df2.mean()

df2.to_excel("Post_test_by_question.xlsx")
